# %% [markdown]
# #### Variables & Data Types

# %%
# Variables
x = 10
name = "Alex"
learning_ai = True

print(x)
print(name)
print(learning_ai)
# Out:
# 10
# Alex
# True

# %%
a = 5        # int
b = 3.14     # float
c = "AI"     # string
d = True     # boolean

print(type(a), type(b), type(c), type(d))
# Out:
# <class 'int'> <class 'float'> <class 'str'> <class 'bool'>

# %% [markdown]
# ## Task 1:

# %% [markdown]
# #### Write code:
#
# - Your name
#
# - Your age
#
# - Your goal (string)
#
# - Print all

# %%
name = "Alex"

age = 22

goal = "Machine Learning"


print(name , age , goal)
# Out:
# Alex 22 Machine Learning
